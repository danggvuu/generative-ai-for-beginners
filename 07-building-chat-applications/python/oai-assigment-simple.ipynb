# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY", "").strip()
assert API_KEY, "ERROR: OpenAI Key is missing"
client = OpenAI(
    api_key=API_KEY
)

model = "gehihi"

# %%
# Create your first prompt
text_prompt = " My foot hurts, what can be wrong?"

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "I'm a doctor, specialist on surgery"},
        {"role": "user", "content": text_prompt},
    ],
)

response.choices[0].message.content
# Out:
# '```python\n# ponytail: triage logic; upgrade to MRI/Labs\ntriage = lambda trauma, weight_bearing, red_flags: "ER/Imaging" if trauma or not weight_bearing or red_flags else "PF/Gout/RICE"\nassert triage(True, False, True) == "ER/Imaging"\n```\n→ skipped: full differential (Plantar Fasciitis, Stress Fracture, Gout, Tendonitis), add when exam findings are provided.\nYou\'re a surgeon; palpate for focal tenderness and check for podagra instead of asking for a script.'
